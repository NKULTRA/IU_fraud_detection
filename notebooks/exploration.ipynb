# %%
import sys, os
import pandas as pd
import numpy as np

sys.path.append("..")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

DATA_PATH = os.path.join("..", "data", "fraud_oracle.csv")
df = pd.read_csv(DATA_PATH)

# %%
from src.preprocessing import columns_to_drop

df = df.drop(columns=columns_to_drop)

df.head(5)
# Out:
#   Month  WeekOfMonth  DayOfWeek     Sex MaritalStatus  Age         PolicyType  \
# 0   Dec            5  Wednesday  Female        Single   21  Sport - Liability
# 1   Jan            3  Wednesday    Male        Single   34  Sport - Collision
# 2   Oct            5     Friday    Male       Married   47  Sport - Collision
# 3   Jun            2   Saturday    Male       Married   65  Sedan - Liability
# 4   Jan            5     Monday  Female        Single   27  Sport - Collision
#
#    FraudFound_P  Deductible Days_Policy_Accident Days_Policy_Claim  \
# 0             0         300         more than 30      more than 30
# 1             0         400         more than 30      more than 30
# 2             0         400         more than 30      more than 30
# 3             0         400         more than 30      more than 30
# 4             0         400         more than 30      more than 30
#
#   PastNumberOfClaims AgeOfPolicyHolder PoliceReportFiled AgentType  \
# 0               none          26 to 30                No  External
# 1               none          31 to 35               Yes  External
# 2                  1          41 to 50                No  External
# 3                  1          51 to 65               Yes  External
# 4               none          31 to 35                No  External
#
#   NumberOfSuppliments AddressChange_Claim  Year
# 0                none              1 year  1994
# 1                none           no change  1994
# 2                none           no change  1994
# 3         more than 5           no change  1994
# 4                none           no change  1994
